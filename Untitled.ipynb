# %%
import pandas as pd
from stemming.porter2 import stem
stem("casually")
file=pd.read_csv('Competition_Train_Data.txt', sep='\t')

# %%
# Out:
# python is /Users/HermanCheung/anaconda/envs/py36/bin/python
# /bin/sh: line 0: type: --version: not found

# %%
# Out:
#       Label  Unique ID                                          #1 String  \
# 0         1     494436  Paul Themba Nyathi, an MDC spokesman, said the...
# 1         1     659182  Pappas said he wouldn't hesitate about asking ...
# 2         1     400946  MSN Messenger 6 will be available for download...
# 3         1     812777  The lies and deceptions from Saddam have been ...
# 4         1     401674  Delta personnel at Atlanta's Hartsfield-Jackso...
# 5         1      10967  Hormone replacement therapy that combines estr...
# 6         0     597218  Kodak said the PracticeWorks deal is expected ...
# 7         1     737629  Selenski had previously spent seven years in p...
# 8         1     680148  County Judge Tim Harley declared a mistrial be...
# 9         1     966413  Agriculture Secretary Luis Lorenzo told Reuter...
# 10        1     951244  The case puts the Supreme Court back into the ...
# 11        0     477398  In a mixture of ancient pagan and modern Chris...
# ...
